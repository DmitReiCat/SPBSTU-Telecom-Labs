# %%
git_hub_link = 'https://raw.githubusercontent.com/DmitReiCat/SPBSTU-Telecom-Labs/master'
your_surname = 'Efimmov'
group = '00201'

# %%
import os
file_names = []
for number in range(1, 10):
  file_names.append('chap0' + str(number))
for number in range(10,12):
  file_names.append('chap' + str(number))

# %%
! mkdir output

# %%
for file_name in file_names:
  if not os.path.exists(file_name + '.ipynb'):
    # !wget { git_hub_link }/{ file_name }/{ file_name }.ipynb
# Out:
# --2023-05-09 22:36:59--  https://raw.githubusercontent.com/DmitReiCat/SPBSTU-Telecom-Labs/master/chap01/chap01.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 571382 (558K) [text/plain]
# Saving to: ‘chap01.ipynb’
#
# chap01.ipynb        100%[===================>] 557.99K  --.-KB/s    in 0.04s
#
# 2023-05-09 22:36:59 (12.7 MB/s) - ‘chap01.ipynb’ saved [571382/571382]
#
# --2023-05-09 22:36:59--  https://raw.githubusercontent.com/DmitReiCat/SPBSTU-Telecom-Labs/master/chap02/chap02.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
  for file_name in file_names:
    if not os.path.exists(file_name + '.html'):
      ! jupyter nbconvert --to html /content/{file_name}.ipynb

# %%
for file_name in file_names:
    if not os.path.exists('output/' + file_name + '.html'):
      ! mv {file_name}.html output/{file_name}_{your_name}_{}.html

# %%
# !zip -r output.zip output
